# %%
# %matplotlib inline
import circro

# %%
my_circ = circro.make_circro_from_dir('data/', edge_cm = 'autumn')

# %%
reload(circro)
# Out:
# <module 'circro' from 'circro.pyc'>

# %%
circro.plot_circro(my_circ)

# %% [markdown]
# Too many edges, let's change the edge threshold

# %%
my_circ.keys()
# Out:
# ['draw_nodes_colorbar',
#  'edge_render_thickness',
#  'node_cm',
#  'edge_cm',
#  'edge_threshold',
#  'start_radian',
#  'edges',
#  'draw_labels',
#  'inner_r',
#  'nodes',
#  '_node_columns']

# %%
my_circ['edge_threshold'] = .95

# %%
circro.plot_circro(my_circ)

# %% [markdown]
# Lets add the labels as another circro

# %%
my_circ['draw_labels'] = False

# %%
my_circ_labels = circro.make_circro(labels='data/labels.csv')

# %%
my_circ_labels['inner_r'] = 2.5

# %%
circro.plot_circros([my_circ_labels, my_circ])

# %% [markdown]
# The node sizes are too large on the outer circro

# %%
type(my_circ_labels['nodes'])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Let's utizilize the advantage of broadcasting and my_circ_labels['nodes'] is a dataframe to broadcast sizes to .2

# %%
my_circ_labels['nodes']['sizes'] = .2

# %%
my_circ_labels['nodes']
# Out:
#          labels  sizes
# left  0     BA1    0.2
#       1     BA2    0.2
#       2     BA3    0.2
#       3     BA4    0.2
#       4     BA5    0.2
#       5     BA6    0.2
#       6     BA7    0.2
#       7     BA8    0.2
#       8     BA9    0.2
#       9    BA10    0.2
#       10   BA11    0.2
#       11   BA12    0.2
#       12   BA13    0.2
#       13   BA14    0.2
#       14   BA15    0.2
#       15   BA16    0.2
#       16   BA17    0.2
#       17   BA18    0.2
#       18   BA19    0.2
#       19   BA20    0.2
# right 0    BA21    0.2
#       1    BA22    0.2
#       2    BA23    0.2
#       3    BA24    0.2
#       4    BA25    0.2
#       5    BA26    0.2
#       6    BA27    0.2
#       7    BA28    0.2
#       8    BA29    0.2
#       9    BA30    0.2
#       10   BA31    0.2
#       11   BA32    0.2
#       12   BA33    0.2
#       13   BA34    0.2
#       14   BA35    0.2
#       15   BA36    0.2
#       16   BA37    0.2
#       17   BA38    0.2
#       18   BA39    0.2
# ...

# %%
circro.plot_circros([my_circ_labels, my_circ])

# %%
my_circ_labels['inner_r']
# Out:
# 2.5

# %%
my_circ_labels['inner_r'] = 2

# %% [markdown]
# Want to change color for labels circro, but forgot which 'nodes' column controls node color, will check my_circ

# %%
my_circ['nodes'].columns
# Out:
# Index([u'colors', u'labels', u'sizes'], dtype='object')

# %%
my_circ_labels['nodes']['colors'] = .5

# %%
my_circ_labels['nodes']
# Out:
#          labels  sizes  colors
# left  0     BA1    0.2     0.5
#       1     BA2    0.2     0.5
#       2     BA3    0.2     0.5
#       3     BA4    0.2     0.5
#       4     BA5    0.2     0.5
#       5     BA6    0.2     0.5
#       6     BA7    0.2     0.5
#       7     BA8    0.2     0.5
#       8     BA9    0.2     0.5
#       9    BA10    0.2     0.5
#       10   BA11    0.2     0.5
#       11   BA12    0.2     0.5
#       12   BA13    0.2     0.5
#       13   BA14    0.2     0.5
#       14   BA15    0.2     0.5
#       15   BA16    0.2     0.5
#       16   BA17    0.2     0.5
#       17   BA18    0.2     0.5
#       18   BA19    0.2     0.5
#       19   BA20    0.2     0.5
# right 0    BA21    0.2     0.5
#       1    BA22    0.2     0.5
#       2    BA23    0.2     0.5
#       3    BA24    0.2     0.5
#       4    BA25    0.2     0.5
#       5    BA26    0.2     0.5
#       6    BA27    0.2     0.5
#       7    BA28    0.2     0.5
#       8    BA29    0.2     0.5
# ...

# %%
circro.plot_circros([my_circ_labels, my_circ])

# %% [markdown]
# The edge weights should be more clearly displayed through the rendered edge thicknesses

# %%
my_circ.keys()
# Out:
# ['draw_nodes_colorbar',
#  'edge_render_thickness',
#  'node_cm',
#  'edge_cm',
#  'edge_threshold',
#  'start_radian',
#  'edges',
#  'draw_labels',
#  'inner_r',
#  'nodes',
#  '_node_columns']

# %%
my_circ['edge_render_thickness'] = [1, 3] #if not set, uses direct edge weight vaules (no transformation) for line thickness

# %%
circro.plot_circros([my_circ_labels, my_circ])

# %% [markdown]
# Good, but small, need to make enlarge figure

# %%
from pylab import rcParams
rcParams['figure.figsize']
# Out:
# (6.0, 4.0)

# %%
rcParams['figure.figsize'] = (12.0, 8.0)

# %%
circro.plot_circros([my_circ_labels, my_circ])

# %%
my_circ['draw_labels'] = True
circro.plot_circro(my_circ)
